# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import pathlib
import os
import seaborn as sns

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
root_dir = Path.cwd().parent.parent
print(root_dir)
folder_raw_data = root_dir / 'data/raw'
folder_processed_data = root_dir / 'data/processed'
folder_external_data = root_dir / 'data/external'
# Out:
# /home/tim/Documents/cdc-birth-data

# %%
# load births_with_geo_apgar_consolidated.csv.gz as df
df = pd.read_csv(folder_processed_data / 'births_with_geo_apgar_consolidated.csv.gz', compression='gzip')
df.head()
# Out:
# /home/tim/miniconda3/envs/cdcbirth/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    dob_yy  dob_mm  mrcntyfips mrcityfips  state_name_mr  mrstatefips  apgar5  \
# 0    1982       1           0        ZZZ  United States            0       1
# 1    1982       1           0        ZZZ  United States            0       3
# 2    1982       1           0        ZZZ  United States            0       5
# 3    1982       1           0        ZZZ  United States            0       6
# 4    1982       1           0        ZZZ  United States            0       7
#
#    births
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df[df['mrcityfips']!='ZZZ']
# Out:
#          dob_yy  dob_mm  mrcntyfips mrcityfips state_name_mr  mrstatefips  \
# 9          1982       1        1001        999       Alabama            1
# 10         1982       1        1001        999       Alabama            1
# 11         1982       1        1001        999       Alabama            1
# 12         1982       1        1001        999       Alabama            1
# 13         1982       1        1001        999       Alabama            1
# ...         ...     ...         ...        ...           ...          ...
# 1925814    2004      12         999      99999       Wyoming           56
# 1925815    2004      12         999      99999       Wyoming           56
# 1925816    2004      12         999      99999       Wyoming           56
# 1925817    2004      12         999      99999       Wyoming           56
# 1925818    2004      12         999      99999       Wyoming           56
#
#          apgar5  births
# 9             5       1
# 10            7       2
# 11            8       6
# 12            9      18
# 13           10      17
# ...         ...     ...
# 1925814       7       4
# 1925815       8      69
# 1925816       9     450
# 1925817      10      58
# 1925818      99       5
#
# [1924260 rows x 8 columns]
