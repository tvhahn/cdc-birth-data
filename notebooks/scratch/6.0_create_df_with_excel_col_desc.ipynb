# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
root_dir = Path.cwd().parent.parent
folder_desc_data = root_dir / 'data/raw/desc/'
folder_raw_data = root_dir / 'data/raw/'
print(folder_desc_data)
# Out:
# c:\_Python\cdc-birth-data\data\raw\desc

# %%
# load df_agg from xlsx
df_labels = pd.read_excel('column_desc.xlsx',)
df_labels.head()
# Out:
#    var_name var_master  trans_req trans_func storage_type disp_format  \
# 0   ab_anti        NaN        NaN        NaN         str1         %1s
# 1   ab_anti        NaN        NaN        NaN         str1         %9s
# 2  ab_aven1        NaN        NaN        NaN         str1         %1s
# 3  ab_aven1        NaN        NaN        NaN         str1         %9s
# 4  ab_aven6        NaN        NaN        NaN         str1         %1s
#
#    min_year  max_year                                       unique_years  \
# 0      2017      2017                                             [2017]
# 1      2004      2016  [2004 2005 2006 2007 2008 2009 2010 2011 2012 ...
# 2      2017      2017                                             [2017]
# 3      2004      2016  [2004 2005 2006 2007 2008 2009 2010 2011 2012 ...
# 4      2017      2017                                             [2017]
#
#                                               desc_1  \
# ...

# %%
year = 1969
std_cols = ['dob_yy']

df_labels[(df_labels['var_master'].isin(std_cols)) & (df_labels['min_year'] <= year) & (df_labels['max_year'] >= year)]
# Out:
#      var_name var_master  trans_req             trans_func storage_type  \
# 122  datayear     dob_yy        1.0  df_dob_yy_byte_to_int         byte
#
#     disp_format  min_year  max_year  \
# 122       %8.0g      1968      1988
#
#                                           unique_years              desc_1  \
# 122  [1968 1969 1970 1971 1972 1973 1974 1975 1976 ...  Data year - (1968)
#
#     desc_2 desc_3 desc_4 desc_5 desc_6 desc_7
# 122    NaN    NaN    NaN    NaN    NaN    NaN

# %%
# load natl1969.csv data from raw data folder
year = 1969
df = pd.read_csv(folder_raw_data / f'natl{year}.csv')
df.head()
# Out:
#    datayear  shipnum  reparea  rectype  restatus  stateres  cntyres  cityres  \
# 0         9        1        0        1         1         1     1001      999
# 1         9        1        0        2         2         1     1026      999
# 2         9        1        0        1         1         1     1001      999
# 3         9        1        0        1         1         1     1001      999
# 4         9        1        0        1         1         1     1001      999
#
#    citrspop smsares  ...  legitsmsarflg  educsmsarflg  congenrflg  \
# 0         9     000  ...              0             0           1
# 1         9     000  ...              0             0           1
# 2         9     000  ...              0             0           1
# 3         9     000  ...              0             0           1
# 4         9     000  ...              0             0           1
#
#    legitstoflg  educstoflg  lmpoflg  monpreoflg  llboflg  lfdoflg  congenflg
# ...

# %%
def create_standardized_df(df, df_labels, year, std_cols):
