# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import pathlib
import os
import zipfile

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# to check CPU count
import multiprocessing
print('CPUs avail:', multiprocessing.cpu_count()) # or os.cpu_count()

# memory available
# https://stackoverflow.com/a/48140392/9214620
# !cat /proc/meminfo | grep Mem
# Out:
# CPUs avail: 32
# MemTotal:       131624760 kB
# MemFree:        107699616 kB
# MemAvailable:   125952588 kB

# %% [markdown]
# First, we will import the 2019 CDC raw data file.

# %%
root_dir = Path.cwd()
folder_raw_data = root_dir / 'data/raw'

# %%
# !pwd
# Out:
# /project/6047694/tvhahn/cdc_infant

# %%
# extract  from the zip file
extract_data = False
if extract_data:
    with zipfile.ZipFile(folder_raw_data / 'Nat2019us.zip', 'r') as zip_ref:
        zip_ref.extractall(folder_raw_data)

# %% [markdown]
# Load the 2019 data. We'll load it all. **Warning: you need lots of RAM for this**

# %%
data_file = folder_raw_data / 'birth_2019_nber_us_v2.csv'

# %%
df = pd.read_csv(data_file,)
# Out:
# /home/tvhahn/jupyter1/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (9,23,169,172,180) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    laterec  dob_yy  dob_mm  dob_tt  dob_wk  bfacil  f_bfacil  bfacil3  \
# 0      NaN    2019       1    1135       3       1         1        1
# 1      NaN    2019       1    1305       3       1         1        1
# 2      NaN    2019       1     800       3       1         1        1
# 3      NaN    2019       1     130       4       1         1        1
# 4      NaN    2019       1    1426       4       1         1        1
#
#    mageimp magerep  ...  f_ca_cleftlip  f_ca_cleft  f_ca_downs  f_ca_chrom  \
# 0      NaN     NaN  ...              1           1           1           1
# 1      NaN     NaN  ...              1           1           1           1
# 2      NaN     NaN  ...              1           1           1           1
# 3      NaN     NaN  ...              1           1           1           1
# 4      NaN     NaN  ...              1           1           1           1
#
#    f_ca_hypos  no_congen  itran  ilive  bfed  f_bfed
# ...

# %% [markdown]
# Reading the documentation, there is no geographic data. From NBER: "The 2005 public use data from 2005-on does not include geographic detail due to restrictions imposed by the states."

# %%
# find columns that are used
list(df.columns)
# Out:
# ['laterec',
#  'dob_yy',
#  'dob_mm',
#  'dob_tt',
#  'dob_wk',
#  'bfacil',
#  'f_bfacil',
#  'bfacil3',
#  'mageimp',
#  'magerep',
#  'mager',
#  'mager14',
#  'mager9',
#  'mbstate_rec',
#  'restatus',
#  'mrace31',
#  'mrace6rec',
#  'mrace15rec',
#  'mbrace',
#  'mraceimp',
#  'mhisp_r',
#  'f_mhisp',
#  'mracehisp',
#  'mar_p',
#  'dmar',
#  'mar_imp',
#  'f_mar_p',
#  'meduc',
#  'f_meduc',
#  'fagerpt_flg',
#  'fagecomb',
#  'fagerec11',
#  'frace31',
#  'frace6rec',
#  'frace15rec',
#  'fbrace',
#  'fhisp_r',
#  'f_fhisp',
#  'fracehisp',
#  'feduc',
#  'f_feduc',
#  'priorlive',
#  'priordead',
#  'priorterm',
#  'lbo_rec',
#  'tpo_rec',
#  'illb_r',
#  'illb_r11',
#  'iloo_r',
#  'iloo_r11',
#  'ilp_r',
#  'ilp_r11',
#  'precare',
#  'f_mpcb',
#  'precare5',
#  'previs',
#  'previs_rec',
#  'f_tpcv',
#  'wic',
#  'f_wic',
#  'cig_0',
#  'cig_1',
#  'cig_2',
#  'cig_3',
#  'cig0_r',
#  'cig1_r',
#  'cig2_r',
#  'cig3_r',
#  'f_cigs_0',
#  'f_cigs_1',
#  'f_cigs_2',
# ...
